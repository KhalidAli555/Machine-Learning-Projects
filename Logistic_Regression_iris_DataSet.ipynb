# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e274da7-b779-483c-a8d4-e74748698383" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e274da7-b779-483c-a8d4-e74748698383">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(r"Iris_Data.csv")

# %%
data
# Out:
#       SL   SW   PL   PW Classification
# 0    5.0  3.5  1.3  0.3              1
# 1    7.9  3.8  6.4  2.0              2
# 2    5.8  2.8  5.1  2.4              2
# 3    5.7  2.6  3.5  1.0              3
# 4    5.4  3.9  1.7  0.4              1
# ..   ...  ...  ...  ...            ...
# 145  4.8  3.0  1.4  0.1              1
# 146  6.5  3.0  5.8  2.2              2
# 147  5.1  3.3  1.7  0.5              1
# 148  5.0  2.0  3.5  1.0              3
# 149  5.7  4.4  1.5  0.4              1
#
# [150 rows x 5 columns]

# %%
data['Classification'].unique()
# Out:
# array(['Setosa', 'Virginica', 'Versicolor'], dtype=object)

# %%
data['Classification'].replace({'Setosa':'1', 'Virginica':'2', 'Versicolor':'3'},inplace=True)

# %%
data
# Out:
#       SL   SW   PL   PW Classification
# 0    5.0  3.5  1.3  0.3              1
# 1    7.9  3.8  6.4  2.0              2
# 2    5.8  2.8  5.1  2.4              2
# 3    5.7  2.6  3.5  1.0              3
# 4    5.4  3.9  1.7  0.4              1
# ..   ...  ...  ...  ...            ...
# 145  4.8  3.0  1.4  0.1              1
# 146  6.5  3.0  5.8  2.2              2
# 147  5.1  3.3  1.7  0.5              1
# 148  5.0  2.0  3.5  1.0              3
# 149  5.7  4.4  1.5  0.4              1
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(data[['SL','SW','PL','PW']],data['Classification'],test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
Logreg=LogisticRegression()

# %% [markdown]
# Model Training

# %%
Logreg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Testing

# %%
Logreg.predict(x_test)
# Out:
# array(['3', '1', '3', '1', '2', '1', '1', '3', '1', '1', '1', '2', '2',
#        '2', '2', '1', '2', '3', '1', '1', '1', '1', '3', '3', '1', '1',
#        '3', '1', '1', '3'], dtype=object)

# %% [markdown]
# check Accuracy

# %%
Logreg.score(x_test,y_test)
# Out:
# 1.0
